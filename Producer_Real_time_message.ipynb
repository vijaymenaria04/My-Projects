# %%
from kafka.admin import KafkaAdminClient, NewTopic
from kafka import KafkaProducer
import json
import time
import random

# %%
topic_name = 'synthetic-data'

# %%
admin_client = KafkaAdminClient(
    bootstrap_servers='localhost:9092',
    client_id='topic_creator'
)
# Out:
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 admin_client = KafkaAdminClient(
#       2     bootstrap_servers='localhost:9092',
#       3     client_id='topic_creator'
#       4 )
#
# File c:\Users\HP\anaconda3\Lib\site-packages\kafka\admin\client.py:208, in KafkaAdminClient.__init__(self, **configs)
#     205 reporters = [reporter() for reporter in self.config['metric_reporters']]
#     206 self._metrics = Metrics(metric_config, reporters)
# --> 208 self._client = KafkaClient(metrics=self._metrics,
#     209                            metric_group_prefix='admin',
#     210                            **self.config)
#     211 self._client.check_version(timeout=(self.config['api_version_auto_timeout_ms'] / 1000))
#     213 # Get auto-discovered version from client if necessary
#
# File c:\Users\HP\anaconda3\Lib\site-packages\kafka\client_async.py:244, in KafkaClient.__init__(self, **configs)
#     242 if self.config['api_version'] is None:
#     243     check_timeout = self.config['api_version_auto_timeout_ms'] / 1000
# --> 244     self.config['api_version'] = self.check_version(timeout=check_timeout)
#
# File c:\Users\HP\anaconda3\Lib\site-packages\kafka\client_async.py:927, in KafkaClient.check_version(self, node_id, timeout, strict)
#     924 # Timeout
#     925 else:
#     926     self._lock.release()
# --> 927     raise Errors.NoBrokersAvailable()
#
# NoBrokersAvailable: NoBrokersAvailable

# %%
topic_list = []
topic_list.append(NewTopic(name=topic_name, num_partitions=1, replication_factor=1))

# %%
try:
    admin_client.create_topics(new_topics=topic_list, validate_only=False)
    print(f"Topic '{topic_name}' created successfully.")
except Exception as e:
    print(f"An error occurred while creating the topic: {e}")

# %%
admin_client.close()

# %%
producer = KafkaProducer(
    bootstrap_servers=['localhost:9092'],
    value_serializer=lambda x: json.dumps(x).encode('utf-8')
)

# %%
def generate_synthetic_data():
    data = {
        'sensor_id': random.randint(1, 100),
        'temperature': round(random.uniform(20.0, 30.0), 2),
        'timestamp': time.time()
    }
    return data

# %%
try:
    while True:
        data = generate_synthetic_data()
        producer.send('synthetic-data', value=data)
        print(f"Sent: {data}")
        time.sleep(1)
except KeyboardInterrupt:
    print("Data generation stopped.")
